# %% [markdown]
# <a href="https://colab.research.google.com/github/GouriNayak/DMDW/blob/main/DataSetImporting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url = 'https://raw.githubusercontent.com/GouriNayak/DMDW/main/Data.csv'

# %%
import pandas as pd

# %%
data =pd.read_csv(url)

# %%
data
# Out:
#    age gender   income  spending
# 0   22       m   18000      6000
# 1   25       f   30000      8000
# 2   31       f   35000     12000
# 3   35       m   40000     18000

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0ec48884-0d8e-417e-84ec-ef939badf97f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0ec48884-0d8e-417e-84ec-ef939badf97f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Data.csv to Data (1).csv

# %%
data
# Out:
#    age gender   income  spending
# 0   22       m   18000      6000
# 1   25       f   30000      8000
# 2   31       f   35000     12000
# 3   35       m   40000     18000

# %%
import io

# %%
df1 = pd.read_csv(io.BytesIO(uploaded['Data.csv']))

# %%
data
# Out:
#    age gender   income  spending
# 0   22       m   18000      6000
# 1   25       f   30000      8000
# 2   31       f   35000     12000
# 3   35       m   40000     18000

# %%
import numpy

# %%
arr=numpy.array([1,2,3,4,5])

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
import numpy as np

# %%
print('np._version_')
# Out:
# np._version_

# %%
import numpy as np

# %%
arr=np.array([1,2,3,4,5])

# %%
print(arr)
# Out:
# [1 2 3 4 5]

# %%
print(type(arr))
# Out:
# <class 'numpy.ndarray'>
