# %% [markdown]
# **LIST**  (A list is a collection which is ordered and changeable. In Python lists are written with square brackets.)

# %%
#LIST and Its Default Methods
lst=["GOURI","SANKAR","teacher",1914,8018054328]
lst
# Out:
# ['GOURI', 'SANKAR', 'teacher', 1914, 8018054328]

# %%
print ("First Element: ", lst[0])
print ("Second Element: ", lst[1])
# Out:
# First Element:  GOURI
# Second Element:  SANKAR

# %%
print("List1=",lst[2:])
# Out:
# List1= ['teacher', 1914, 8018054328]

# %%
print("List1=",lst[-1])
# Out:
# List1= 8018054328

# %%
print("List1=",lst[-1:])
# Out:
# List1= [8018054328]

# %%
print("List1=",lst[1:-1])
# Out:
# List1= ['SANKAR', 'teacher', 1914]

# %%
#len():Gives the total length of the list.
len(lst)
# Out:
# 5

# %%
#max():Returns item from the list with max value.
lst1=[10,109,887,60,890]
max(lst1)
# Out:
# 890

# %%
#min():Returns item from the list with min value.
min(lst1)
# Out:
# 10

# %%
#list():Converts a tuple into list.
tpl=("hii","hello","welcome")
list(tpl)
# Out:
# ['hii', 'hello', 'welcome']

# %%
#append():Appends object obj to list.
lst.append("Welcome to all")
lst
# Out:
# ['GOURI', 'SANKAR', 'teacher', 1914, 8018054328, 'Welcome to all']

# %%
#count():Returns count of how many times obj occurs in list
lst2=[1,3,4,5,4,3,6,5,7,3,4,1,1]
lst2.count(4)
# Out:
# 3

# %%
#extend():Appends the contents of seq to list
tpl1=(1,2,3)
lst.extend(tpl1)
lst
# Out:
# ['GOURI', 'SANKAR', 'teacher', 1914, 8018054328, 'Welcome to all', 1, 2, 3]

# %%
del lst[9:15]
lst
# Out:
# ['GOURI', 'SANKAR', 'teacher', 1914, 8018054328, 'Welcome to all', 1, 2, 3]

# %%
del lst[8:]
lst
# Out:
# ['GOURI', 'SANKAR', 'teacher', 1914, 8018054328, 'Welcome to all', 1, 2]

# %%
#index():Returns the lowest index in list that obj appears
lst.index('teacher')
# Out:
# 2

# %%
lst2.index(3)
# Out:
# 1

# %%
#insert():Inserts object obj into list at offset index
lst.insert(2,"Good night")
lst
# Out:
# ['GOURI',
#  'SANKAR',
#  'Good night',
#  'teacher',
#  1914,
#  8018054328,
#  'Welcome to all',
#  1,
#  2]

# %%
#pop():Removes and returns last object or obj from list
lst.pop()
lst
# Out:
# ['GOURI',
#  'SANKAR',
#  'Good night',
#  'teacher',
#  1914,
#  8018054328,
#  'Welcome to all',
#  1]

# %%
#remove():Removes object obj from list
lst.remove('Welcome to all')
lst
# Out:
# ['GOURI', 'SANKAR', 'Good night', 'teacher', 1914, 8018054328, 1]

# %%
#reverse():Reverses objects of list in place
lst.reverse()

# %%
lst
# Out:
# [1, 8018054328, 1914, 'teacher', 'Good night', 'SANKAR', 'GOURI']

# %%
#sort():Sorts objects of list, use compare func if given
lst2.sort()
lst2
# Out:
# [1, 1, 1, 3, 3, 3, 4, 4, 4, 5, 5, 6, 7]

# %% [markdown]
# **DICTIONARY**  (A dictionary is a collection which is unordered, changeable and indexed. In Python dictionaries are written with curly brackets, and they have keys and values.)

# %%
dit={"name":"GOURI","age":26, "profession":"TEACHER", "Address":"GUNUPUR"}
dit
# Out:
# {'Address': 'GUNUPUR', 'age': 26, 'name': 'GOURI', 'profession': 'TEACHER'}

# %%
#len():Gives the total length of the dictionary. This would be equal to the number of items in the dictionary.
len(dit)
# Out:
# 4

# %%
#str():Produces a printable string representation of a dictionary
str(dit)
# Out:
# "{'name': 'GOURI', 'age': 26, 'profession': 'TEACHER', 'Address': 'GUNUPUR'}"

# %%
#type():Returns the type of the passed variable. If passed variable is dictionary, then it would return a dictionary type.
type(dit)
# Out:
# dict

# %%
#copy():Returns a shallow copy of dictionary dict
dit.copy()
# Out:
# {}

# %%
#fromkeys():Create a new dictionary with keys from seq and values set to value.
dit.fromkeys("name")
# Out:
# {'a': None, 'e': None, 'm': None, 'n': None}

# %%
#get():For key key, returns value or default if key not in dictionary.
dit.get("age")
# Out:
# 26

# %%
#items():Returns a list of dict's (key, value) tuple pairs
dit.items()
# Out:
# dict_items([('name', 'GOURI'), ('age', 26), ('profession', 'TEACHER'), ('Address', 'GUNUPUR')])

# %%
#keys():Returns list of dictionary dict's keys
dit.keys()
# Out:
# dict_keys(['name', 'age', 'profession', 'Address'])

# %%
#setdefault():Similar to get(), but will set dict[key] = default if key is not already in dict
dit.setdefault("DOB","05-07-1988")
# Out:
# '05-07-1988'

# %%
#values():Returns list of dictionary dict's values
dit.values()

# %%
#clear():Removes all elements of dictionary dict
dit.clear()

# %%
dit
# Out:
# {}

# %% [markdown]
# **SET** (A set is a collection which is unordered and unindexed. In Python, sets are written with curly brackets.)

# %%
set1={"apple","banana","Orange","Mango"}
set1
# Out:
# {'Mango', 'Orange', 'apple', 'banana'}

# %%
for i in set1:
  print(i)
# Out:
# apple
# Mango
# Orange
# banana

# %%
#Once a set is created, you cannot change its items, but you can add new items.
#add():To add one item to a set use the add() method.
set1.add("strawberry")
set1
# Out:
# {'Mango', 'Orange', 'apple', 'banana', 'strawberry'}

# %%
#update():To add more than one item to a set use the update() method.
set2={"apple","banana","Orange","Mango"}
set2.update(["cherry","blueberry","plum"])
set2
# Out:
# {'Mango', 'Orange', 'apple', 'banana', 'blueberry', 'cherry', 'plum'}

# %%
#len():returns the length of the set.
len(set2)
# Out:
# 7

# %%
#remove():Removes an item from the set.
set2.remove("plum")
set2
# Out:
# {'Mango', 'Orange', 'apple', 'banana', 'blueberry', 'cherry'}

# %%
#discard():Removes an item from the set.
set2.discard("apple")
set2
# Out:
# {'Mango', 'Orange', 'banana', 'blueberry', 'cherry'}

# %%
#pop():Remove the last item by using the pop() method
set2.pop()
set2
# Out:
# {'Mango', 'Orange', 'banana', 'cherry'}

# %%
#union():method returns a new set with all items from both sets
s1={1,2,3}
s2={"a","b","c"}
s3=s1.union(s2)
s3
# Out:
# {1, 2, 3, 'a', 'b', 'c'}

# %% [markdown]
# **TUPLE** (In Python, a tuple is similar to List except that the objects in tuple are immutable which means we cannot change the elements of a tuple once assigned. On the other hand, we can change the elements of a list.)

# %%
tpl=(10,20,30,40,50)
tpl
# Out:
# (10, 20, 30, 40, 50)

# %%
print("First element:",tpl[0])
# Out:
# First element: 10

# %%
print("Element:",tpl[1:4])
# Out:
# Element: (20, 30, 40)

# %%
tpl1=("a","b","c","d")
tpl1
# Out:
# ('a', 'b', 'c', 'd')

# %%
#Concatenation of the tuple
tpl2=tpl+tpl1
tpl2
# Out:
# (10, 20, 30, 40, 50, 'a', 'b', 'c', 'd')

# %%
#Length of the tuple
len(tpl2)
# Out:
# 9

# %%
#Repeatation of the Tuple
tpl*2
# Out:
# (10, 20, 30, 40, 50, 10, 20, 30, 40, 50)

# %%
#Membership of the tuple
30 in tpl
# Out:
# True

# %%
#Iteration
for x in tpl:
  print(x)
# Out:
# 10
# 20
# 30
# 40
# 50

# %%
#len():Gives the total length of the tuple.
len(tpl)
# Out:
# 5

# %%
#max():Returns item from the tuple with max value.
max(tpl)
# Out:
# 50

# %%
#min():Returns item from the tuple with min value.
min(tpl)
# Out:
# 10

# %% [markdown]
# **STRING** (A string is a sequence of one or more characters (letters, numbers, symbols) that can be either a constant or a variable. Made up of Unicode, strings are immutable sequences, meaning they are unchanging.)

# %%
var1 = 'Hello World!'
var2 = "Python Programming"

print ("var1[0]: ", var1[0])
print ("var2[1:5]: ", var2[1:5])
# Out:
# var1[0]:  H
# var2[1:5]:  ytho

# %%
#Capitalizes first letter of string
var1.capitalize()
# Out:
# 'Hello world!'

# %%
#Returns true if string contains only digits and false otherwise.
var1.isdigit()
# Out:
# False

# %%
#Returns the length of the string
len(var1)
# Out:
# 12

# %%
#Converts all uppercase letters in string to lowercase.
var1.lower()
# Out:
# 'hello world!'

# %%
#Returns the max alphabetical character from the string str.
max(var1)
# Out:
# 'r'
